# %%
# ============================================================
# 🌱 Plant Disease Dataset Splitter (80/10/10)
# ============================================================
# ✅ This notebook splits your dataset (e.g., plant → disease → images)
#    into train, val, and test sets using symbolic links.
# ⚡ Super fast, minimal disk usage, and keeps folder structure.
# ============================================================

import os
import random
from pathlib import Path

print("✅ Imports loaded successfully.")
# Out:
# ✅ Imports loaded successfully.

# %%
# ------------------------------------------------------------
# 🗂️ Define your dataset directories
# ------------------------------------------------------------
# Change these paths to match your local setup

src_root = Path(r"C:\Users\paul\Downloads\archive (2)\MergedDataset")     # 📁 Original dataset
dst_root = Path(r"C:\Users\paul\Downloads\archive (2)\MergedDataset\split_dataset")    # 📁 Output split dataset

# Define split ratios (Train:Val:Test)
splits = ["train", "val", "test"]
ratios = [0.8, 0.1, 0.1]  # 80%, 10%, 10%

print(f"Source: {src_root}")
print(f"Destination: {dst_root}")
print(f"Splits: {splits} | Ratios: {ratios}")
# Out:
# Source: C:\Users\paul\Downloads\archive (2)\MergedDataset
# Destination: C:\Users\paul\Downloads\archive (2)\MergedDataset\split_dataset
# Splits: ['train', 'val', 'test'] | Ratios: [0.8, 0.1, 0.1]

# %%
# ------------------------------------------------------------
# 🔗 Create a symbolic link instead of copying files
# ------------------------------------------------------------
def make_symlink(src, dst):
    """
    Create a symbolic link pointing to the original image.
    Works like a shortcut — saves space and time.
    """
    try:
        dst.symlink_to(src)
    except Exception as e:
        print(f"⚠️ Could not create symlink for {src.name}: {e}")

print("✅ Symlink function ready.")
# Out:
# ✅ Symlink function ready.

# %%
# ------------------------------------------------------------
# 🔀 Split the dataset into train/val/test folders
# ------------------------------------------------------------
def split_dataset():
    total_count = {"train": 0, "val": 0, "test": 0}

    # Loop through each plant category
    for plant_dir in src_root.iterdir():
        if not plant_dir.is_dir():
            continue

        # Loop through each disease/subfolder under that plant
        for subfolder in plant_dir.iterdir():
            if not subfolder.is_dir():
                continue

            # List all images
            images = list(subfolder.glob("*.*"))
            random.shuffle(images)

            n = len(images)
            n_train = int(n * ratios[0])
            n_val = int(n * ratios[1])

            subsets = {
                "train": images[:n_train],
                "val": images[n_train:n_train + n_val],
                "test": images[n_train + n_val:]
            }

            # Create split directories and symbolic links
            for split in splits:
                split_dir = dst_root / split / plant_dir.name / subfolder.name
                split_dir.mkdir(parents=True, exist_ok=True)

                for img_path in subsets[split]:
                    link_path = split_dir / img_path.name
                    if not link_path.exists():
                        make_symlink(img_path, link_path)

                total_count[split] += len(subsets[split])

            # Print summary for this subfolder
            print(f"📁 {plant_dir.name}/{subfolder.name}: "
                  f"train={len(subsets['train'])}, "
                  f"val={len(subsets['val'])}, "
                  f"test={len(subsets['test'])}")

    # Print overall summary
    print("\n✅ Dataset split completed using symbolic links (no duplication).")
    print("------------------------------------------------------------")
    for split, count in total_count.items():
        print(f"{split.upper():5}: {count} images")
    print("------------------------------------------------------------")

print("✅ Split logic function ready.")
# Out:
# ✅ Split logic function ready.

# %%
# ------------------------------------------------------------
# 🚀 Execute the dataset split
# ------------------------------------------------------------
split_dataset()
# Out:
# 📁 Apple/Apple scab: train=504, val=63, test=63
# 📁 Apple/Black rot: train=563, val=70, test=71
# 📁 Apple/Cedar apple rust: train=220, val=27, test=28
# 📁 Apple/Healthy: train=1386, val=173, test=174
# 📁 Apple/Mosaic virus: train=71, val=8, test=10
# 📁 Apple/Rust: train=196, val=24, test=25
# 📁 Apple/Scab: train=280, val=35, test=36
# 📁 Banana/Anthracnose: train=56, val=7, test=8
# 📁 Banana/Black streak: train=133, val=16, test=18
# 📁 Banana/Bunchy top: train=125, val=15, test=17
# 📁 Banana/Cigar end rot: train=48, val=6, test=6
# 📁 Banana/Cordana spot: train=44, val=5, test=6
# 📁 Banana/Panama disease: train=50, val=6, test=7
# 📁 Basil/Downy mildew: train=50, val=6, test=7
# 📁 Bean/Halo blight: train=44, val=5, test=7
# 📁 Bean/Mosaic virus: train=46, val=5, test=7
# 📁 Bean/Rust: train=92, val=11, test=12
# 📁 Blueberry/Anthracnose: train=33, val=4, test=5
# 📁 Blueberry/Botrytis blight: train=28, val=3, test=5
# 📁 Blueberry/Healthy: train=1295, val=161, test=163
# 📁 Blueberry/Mummy berry: train=37, val=4, test=6
# 📁 Blueberry/Rust: train=35, val=4, test=5
# 📁 Blueberry/Scorch: train=34, val=4, test=5
# 📁 Broccoli/Alternaria spot: train=52, val=6, test=7
# 📁 Broccoli/Downy mildew: train=23, val=2, test=4
# 📁 Broccoli/Ring spot: train=12, val=1, test=3
# 📁 Cabbage/Alternaria spot: train=50, val=6, test=7
# 📁 Cabbage/Black rot: train=104, val=13, test=14
# 📁 Cabbage/Downy mildew: train=67, val=8, test=9
# 📁 Carrot/Alternaria blight: train=48, val=6, test=6
# 📁 Carrot/Cavity spot: train=57, val=7, test=8
# 📁 Carrot/Cercospora blight: train=15, val=1, test=3
# 📁 Cauliflower/Alternaria spot: train=43, val=5, test=6
# 📁 Cauliflower/Bacterial soft rot: train=28, val=3, test=5
# 📁 Celery/Anthracnose: train=23, val=2, test=4
# 📁 Celery/Early blight: train=28, val=3, test=5
# 📁 Cherry/Healthy: train=728, val=91, test=92
# 📁 Cherry/Powdery mildew: train=868, val=108, test=109
# 📁 Cherry/Spot: train=85, val=10, test=12
# 📁 Citrus/Canker: train=312, val=39, test=39
# 📁 Citrus/Greening disease: train=106, val=13, test=14
# 📁 Citrus/Haunglongbing (citrus greening): train=4405, val=550, test=552
# 📁 Coffee/Berry blotch: train=94, val=11, test=13
# 📁 Coffee/Black rot: train=5, val=0, test=2
# 📁 Coffee/Brown eye spot: train=16, val=2, test=2
# 📁 Coffee/Rust: train=127, val=15, test=17
# 📁 Corn/Blight: train=155, val=19, test=20
# 📁 Corn/Cercospora leaf spot gray leaf spot: train=410, val=51, test=52
# 📁 Corn/Common rust: train=953, val=119, test=120
# 📁 Corn/Gray spot: train=139, val=17, test=18
# 📁 Corn/Healthy: train=929, val=116, test=117
# 📁 Corn/Northern blight: train=104, val=13, test=13
# 📁 Corn/Northern leaf blight: train=788, val=98, test=99
# 📁 Corn/Rust: train=235, val=29, test=30
# 📁 Corn/Smut: train=161, val=20, test=21
# 📁 Cucumber/Angular spot: train=145, val=18, test=19
# 📁 Cucumber/Bacterial wilt: train=86, val=10, test=12
# 📁 Cucumber/Powdery mildew: train=151, val=18, test=20
# 📁 Eggplant/Cercospora spot: train=48, val=6, test=6
# 📁 Eggplant/Phomopsis fruit rot: train=36, val=4, test=6
# 📁 Eggplant/Phytophthora blight: train=26, val=3, test=4
# 📁 Garlic/Blight: train=73, val=9, test=10
# 📁 Garlic/Rust: train=84, val=10, test=12
# 📁 Ginger/Sheath blight: train=54, val=6, test=8
# 📁 Ginger/Spot: train=20, val=2, test=3
# 📁 Grape/Black rot: train=1104, val=138, test=139
# 📁 Grape/Downy mildew: train=224, val=28, test=29
# 📁 Grape/Esca (black measles): train=1106, val=138, test=139
# 📁 Grape/Healthy: train=398, val=49, test=51
# 📁 Grape/Leaf blight (isariopsis leaf spot): train=860, val=107, test=109
# 📁 Grape/Roll disease: train=56, val=7, test=8
# 📁 Grape/Spot: train=72, val=9, test=10
# 📁 Lettuce/Downy mildew: train=67, val=8, test=9
# 📁 Lettuce/Mosaic virus: train=31, val=3, test=5
# 📁 Maple/Tar spot: train=91, val=11, test=12
# 📁 Peach/Anthracnose: train=10, val=1, test=2
# 📁 Peach/Bacterial spot: train=1837, val=229, test=231
# 📁 Peach/Brown rot: train=138, val=17, test=18
# 📁 Peach/Curl: train=145, val=18, test=19
# 📁 Peach/Healthy: train=377, val=47, test=48
# 📁 Peach/Rust: train=6, val=0, test=2
# 📁 Peach/Scab: train=62, val=7, test=9
# 📁 Pepper_bell/Bacterial spot: train=858, val=107, test=108
# 📁 Pepper_bell/Blossom end rot: train=89, val=11, test=12
# 📁 Pepper_bell/Frogeye spot: train=24, val=3, test=4
# 📁 Pepper_bell/Healthy: train=1216, val=152, test=152
# 📁 Pepper_bell/Powdery mildew: train=22, val=2, test=4
# 📁 Pepper_bell/Spot: train=66, val=8, test=9
# 📁 Plum/Bacterial spot: train=12, val=1, test=3
# 📁 Plum/Brown rot: train=64, val=8, test=9
# 📁 Plum/Pocket disease: train=45, val=5, test=7
# 📁 Plum/Pox virus: train=26, val=3, test=4
# 📁 Plum/Rust: train=27, val=3, test=4
# 📁 Potato/Early blight: train=1037, val=129, test=131
# 📁 Potato/Healthy: train=121, val=15, test=16
# 📁 Potato/Late blight: train=1060, val=132, test=133
# 📁 Raspberry/Fire blight: train=27, val=3, test=4
# 📁 Raspberry/Gray mold: train=32, val=4, test=4
# 📁 Raspberry/Healthy: train=392, val=49, test=49
# 📁 Raspberry/Spot: train=15, val=1, test=3
# 📁 Raspberry/Yellow rust: train=29, val=3, test=5
# 📁 Rice/Blast: train=66, val=8, test=9
# 📁 Rice/Sheath blight: train=60, val=7, test=9
# 📁 Soybean/Bacterial blight: train=72, val=9, test=10
# 📁 Soybean/Brown spot: train=56, val=7, test=8
# 📁 Soybean/Downy mildew: train=122, val=15, test=16
# 📁 Soybean/Frog eye spot: train=190, val=23, test=25
# 📁 Soybean/Healthy: train=4124, val=515, test=516
# 📁 Soybean/Mosaic: train=93, val=11, test=13
# 📁 Soybean/Rust: train=94, val=11, test=13
# 📁 split_dataset/test: train=0, val=0, test=0
# 📁 split_dataset/train: train=0, val=0, test=0
# 📁 split_dataset/val: train=0, val=0, test=0
# 📁 Squash/Bacterial wilt: train=64, val=8, test=9
# 📁 Squash/Downy mildew: train=36, val=4, test=5
# 📁 Squash/Powdery mildew: train=1896, val=237, test=237
# 📁 Squash/Yellow mosaic virus: train=76, val=9, test=10
# 📁 Strawberry/Anthracnose: train=46, val=5, test=7
# 📁 Strawberry/Healthy: train=441, val=55, test=56
# 📁 Strawberry/Leaf scorch: train=887, val=110, test=112
# 📁 Strawberry/Scorch: train=31, val=3, test=5
# 📁 Tobacco/Blue mold: train=48, val=6, test=6
# 📁 Tobacco/Brown spot: train=52, val=6, test=8
# 📁 Tobacco/Frogeye spot: train=22, val=2, test=4
# 📁 Tobacco/Mosaic virus: train=32, val=4, test=5
# 📁 Tomato/Bacterial spot: train=1877, val=234, test=236
# 📁 Tomato/Early blight: train=1020, val=127, test=128
# 📁 Tomato/Healthy: train=1314, val=164, test=165
# 📁 Tomato/Late blight: train=1746, val=218, test=219
# 📁 Tomato/Leaf mold: train=761, val=95, test=96
# 📁 Tomato/Mold: train=197, val=24, test=26
# 📁 Tomato/Mosaic virus: train=93, val=11, test=13
# 📁 Tomato/Septoria leaf spot: train=1416, val=177, test=178
# 📁 Tomato/Septoria spot: train=229, val=28, test=30
# 📁 Tomato/Spider mites two-spotted spider mite: train=1340, val=167, test=169
# 📁 Tomato/Target spot: train=1123, val=140, test=141
# 📁 Tomato/Tomato mosaic virus: train=298, val=37, test=38
# 📁 Tomato/Tomato yellow leaf curl virus: train=4285, val=535, test=537
# 📁 Tomato/Two spotted spider mites: train=1, val=0, test=1
# 📁 Tomato/Yellow curl virus: train=74, val=9, test=10
# 📁 Tomato/Yellow virus: train=190, val=23, test=25
# 📁 Wheat/Bacterial streak black chaff: train=93, val=11, test=13
# 📁 Wheat/Head scab: train=255, val=31, test=33
# 📁 Wheat/Loose smut: train=172, val=21, test=22
# 📁 Wheat/Powdery mildew: train=216, val=27, test=28
# 📁 Wheat/Rust: train=105, val=13, test=14
# 📁 Wheat/Septoria blotch: train=185, val=23, test=24
# 📁 Wheat/Stem rust: train=118, val=14, test=16
# 📁 Wheat/Stripe rust: train=286, val=35, test=37
#
# ✅ Dataset split completed using symbolic links (no duplication).
# ------------------------------------------------------------
# TRAIN: 54911 images
# VAL  : 6807 images
# TEST : 6997 images
# ------------------------------------------------------------
